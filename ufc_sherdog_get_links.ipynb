# %%
import cloudscraper
import requests
import time
import random
import json
from bs4 import BeautifulSoup
from googlesearch import search

# %%
base_url = "https://www.ufc.com/athletes/all"
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/114.0.0.0 Safari/537.36"
    )
}

page = 1
all_data = []  # Will store tuples: (athlete_name, full_profile_link)
reported_hundreds = 0

while True:
    params = {
        "gender": "All",
        "search": "",
        "page": page
    }
    response = requests.get(base_url, headers=headers, params=params)
    
    if response.status_code != 200:
        print("Error: Status code", response.status_code)
        break

    soup = BeautifulSoup(response.content, "html.parser")
    
    # Find all athlete cards
    cards = soup.find_all("div", class_="c-listing-athlete-flipcard")
    if not cards:
        print("No athlete cards found on page", page, "- exiting loop.")
        break

    for card in cards:
        # Look for the <a> element whose class contains "e-button--black"
        link_tag = card.find("a", class_=lambda x: x and "e-button--black" in x)
        if link_tag:
            text_tag = link_tag.find("span", class_="e-button__text")
            if text_tag and "Athlete Profile" in text_tag.get_text(strip=True):
                href = link_tag.get("href")
                # Build full URL if the href is relative.
                if href.startswith("/"):
                    full_link = "https://www.ufc.com" + href
                else:
                    full_link = href
                # Find the athlete name in the card.
                name_tag = card.find("span", class_="c-listing-athlete__name")
                athlete_name = name_tag.get_text(strip=True) if name_tag else "Unknown"
                all_data.append((athlete_name, full_link))
    
    if len(all_data) // 110 > reported_hundreds:
        reported_hundreds = len(all_data) // 110
        print(f"Total athlete profile links so far: {len(all_data)}")
    
    page += 1

print("Total athlete profile links found:", len(all_data))

# Create an API-like dictionary output with the fighter data
result_ufc = [{"name": name, "profile_url": link} for name, link in all_data]
ufc_fighters = json.dumps(result_ufc, indent=2)

# Print the output as formatted JSON
# print(json.dumps(result, indent=2))

# %%
# Save the results to the specified path
file_path = r'C:\Users\tifek\GitHub\UFC\ufc.json'  # Use raw string notation (r'') for Windows paths
with open(file_path, 'w') as json_file:
    json.dump(result_ufc, json_file, indent=2)

print(f"Results have been saved to '{file_path}'")
# Out:
# Results have been saved to 'C:\Users\tifek\GitHub\UFC\ufc.json'

# %%
from googlesearch import search
import json
import time
import random

result_sd = []
max_retries = 5

for fighter in fighter_names:
    query = f"{fighter} Sherdog"
    retry_count = 0
    fighter_data = {"name": fighter, "url": None}
    
    while retry_count < max_retries:
        try:
            search_results = list(search(query, num_results=1))
            if search_results:
                fighter_data["url"] = search_results[0]
            break  # exit loop on success
        except Exception as e:
            print(f"Error retrieving results for {fighter}: {e}")
            retry_count += 1
            backoff_delay = random.uniform(1, 5) * (2 ** retry_count)
            print(f"Retrying in {backoff_delay:.2f} seconds... (attempt {retry_count}/{max_retries})")
            time.sleep(backoff_delay)
    result_sd.append(fighter_data)
    # Additional random delay before the next fighter's query
    time.sleep(random.uniform(1, 5))

print(json.dumps(result_sd, indent=2))

# %%
# Save the results to the specified path
file_path = r'C:\Users\tifek\GitHub\UFC\sherdog.json'  # Use raw string notation (r'') for Windows paths
with open(file_path, 'w') as json_file:
    json.dump(result_sd, json_file, indent=2)

print(f"Results have been saved to '{file_path}'")
# Out:
# Results have been saved to 'C:\Users\tifek\GitHub\UFC\sherdog.json'

# %%
import json

# Define file paths for both JSON files
sherdog_file_path = r'C:\Users\tifek\GitHub\UFC\sherdog.json'
ufc_file_path = r'C:\Users\tifek\GitHub\UFC\ufc.json'

# Load the contents of 'sherdog.json'
with open(sherdog_file_path, 'r') as sherdog_file:
    sherdog_data = json.load(sherdog_file)

# Load the contents of 'ufc.json'
with open(ufc_file_path, 'r') as ufc_file:
    ufc_data = json.load(ufc_file)

# Display the first 20 entries of each JSON file, if available
print("Sherdog Data (First 20 entries):")
print(json.dumps(sherdog_data[:20], indent=2))  # Slice to get first 20 items

print("\nUFC Data (First 20 entries):")
print(json.dumps(ufc_data[:20], indent=2))  # Slice to get first 20 items
# Out:
# Sherdog Data (First 20 entries):
# [
#   {
#     "name": "Juan Adams",
#     "url": "https://www.sherdog.com/fighter/Juan-Adams-239097"
#   },
#   {
#     "name": "Scott Adams",
#     "url": "https://www.sherdog.com/fighter/Scott-Adams-241"
#   },
#   {
#     "name": "Anthony Adams",
#     "url": "https://www.sherdog.com/fighter/Anthony-Adams-144983"
#   },
#   {
#     "name": "Zarrukh Adashev",
#     "url": "https://www.sherdog.com/fighter/Zarrukh-Adashev-126877"
#   },
#   {
#     "name": "Israel Adesanya",
#     "url": "https://www.sherdog.com/fighter/Israel-Adesanya-56374"
#   },
#   {
#     "name": "Sam Adkins",
#     "url": "https://www.sherdog.com/fighter/Sam-Adkins-122"
#   },
#   {
#     "name": "Nick Agallar",
#     "url": "https://www.sherdog.com/fighter/Nick-Agallar-2295"
#   },
#   {
#     "name": "Mariya Agapova",
#     "url": "https://www.sherdog.com/fighter/Mariya-Agapova-206861"
#   },
#   {
#     "name": "Fabio Agu",
#     "url": "/search?num=3"
#   },
#   {
# ...
